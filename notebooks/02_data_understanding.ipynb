# %%
import pandas as pd

customers = pd.read_csv("../data/olist_customers_dataset.csv")
orders = pd.read_csv("../data/olist_orders_dataset.csv")
items = pd.read_csv("../data/olist_order_items_dataset.csv")
payments = pd.read_csv("../data/olist_order_payments_dataset.csv")
reviews = pd.read_csv("../data/olist_order_reviews_dataset.csv")
products = pd.read_csv("../data/olist_products_dataset.csv")
sellers = pd.read_csv("../data/olist_sellers_dataset.csv")

# %%
print(customers.customer_id.nunique())
print(customers.shape)

print(orders.order_id.nunique())
print(orders.shape)

print(products.product_id.nunique())
print(products.shape)

print(sellers.seller_id.nunique())
print(sellers.shape)
# Out:
# 99441
# (99441, 5)
# 99441
# (99441, 8)
# 32951
# (32951, 9)
# 3095
# (3095, 4)

# %%
items.groupby("order_id").size().describe()
# Out:
# count    98666.000000
# mean         1.141731
# std          0.538452
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         21.000000
# dtype: float64

# %%
payments.groupby("order_id").size().describe()
# Out:
# count    99440.000000
# mean         1.044710
# std          0.381166
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         29.000000
# dtype: float64

# %%
reviews.groupby("order_id").size().describe()
# Out:
# count    98673.000000
# mean         1.005584
# std          0.075060
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          3.000000
# dtype: float64

# %% [markdown]
# ## Data Model Summary
#
# Key observations:
#
# - Customers and Sellers are dimension tables.
# - Orders is the central transactional table.
# - One order can contain multiple order items.
# - One order may have multiple payment records.
# - Reviews are linked at the order level.
# - Products are linked through order items.
